# %% [markdown]
# <a href="https://colab.research.google.com/github/deepaktamil20/19-04-2022-python-exam-eve/blob/main/19BEC4024_ML_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
dataset=pd.read_csv("/content/drive/MyDrive/DATASETS/admission.csv")

# %% [markdown]
# Q1).Perform Exploratory Data Analysis (EDA) tasks

# %% [markdown]
# a). Visualize the 10 random rows of the data set

# %%
dataset.sample(10)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 25           26        340          120                  5  4.5   4.5  9.60
# 472         473        327          116                  4  4.0   4.5  9.48
# 267         268        314          107                  3  3.0   3.5  8.17
# 263         264        324          111                  3  2.5   1.5  8.79
# 88           89        314          108                  3  4.5   3.5  8.14
# 365         366        330          114                  4  4.5   3.0  9.17
# 182         183        299          100                  2  3.0   3.5  7.88
# 277         278        320          101                  2  2.5   3.0  8.62
# 224         225        305          105                  2  3.0   2.0  8.23
# 359         360        321          107                  2  2.0   1.5  8.44
#
#      Research  Chance of Admit
# 25          1              0.94
# 472         1              0.90
# 267         1              0.73
# ...

# %%
dataset=dataset.drop(['Serial No.'],axis=1)

# %% [markdown]
# b) Generate the description for numeric variables

# %%
dataset.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
# checking for missing values

dataset.isna().sum().sort_values(ascending=False)
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# c) Check the shape of the data set

# %%
dataset.shape
# Out:
# (500, 8)

# %% [markdown]
# d) Generate the correlation matrix

# %%
dataset.corr()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.827200           0.635376  0.613498
# TOEFL Score         0.827200     1.000000           0.649799  0.644410
# University Rating   0.635376     0.649799           1.000000  0.728024
# SOP                 0.613498     0.644410           0.728024  1.000000
# LOR                 0.524679     0.541563           0.608651  0.663707
# CGPA                0.825878     0.810574           0.705254  0.712154
# Research            0.563398     0.467012           0.427047  0.408116
# Chance of Admit     0.810351     0.792228           0.690132  0.684137
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.524679  0.825878  0.563398          0.810351
# TOEFL Score        0.541563  0.810574  0.467012          0.792228
# University Rating  0.608651  0.705254  0.427047          0.690132
# ...

# %%
dataset.corr()['Chance of Admit ']
# Out:
# GRE Score            0.810351
# TOEFL Score          0.792228
# University Rating    0.690132
# SOP                  0.684137
# LOR                  0.645365
# CGPA                 0.882413
# Research             0.545871
# Chance of Admit      1.000000
# Name: Chance of Admit , dtype: float64

# %% [markdown]
# e) Generate a correlogram

# %%
#Distribution of dataset columns
import matplotlib.pyplot as plt
fig=dataset.hist(figsize=(10,10),color='lightblue')
plt.show()

# %%
#Pairplot
import seaborn as sns
sns.pairplot(dataset)

# %%
sns.heatmap(dataset.corr(),annot=True,linewidths=1.0)
plt.show()

# %% [markdown]
# Q2).Find out the minimum and maximum values for GRE
# score

# %%
print("Minimum value of GRE SCORE:",dataset['GRE Score'].min())
# Out:
# Minimum value of GRE SCORE: 290

# %%
print("Maximum value of GRE SCORE:",dataset['GRE Score'].max())
# Out:
# Maximum value of GRE SCORE: 340

# %% [markdown]
# Q.3 Find out the percentage of universities for each university rating

# %%
rating=dataset['University Rating'].unique()
rating.sort()
per=[]
v=list(dataset['University Rating'].values)
for i in rating:
  per.append(v.count(i))
print(per)
print("University Rating Percentage:")
for i in range(0,5):
  print('University Rating',i+1,' :',per[i]/5,'%')
# Out:
# [34, 126, 162, 105, 73]
# University Rating Percentage:
# University Rating 1  : 6.8 %
# University Rating 2  : 25.2 %
# University Rating 3  : 32.4 %
# University Rating 4  : 21.0 %
# University Rating 5  : 14.6 %

# %% [markdown]
# Q.4 Convert the target variable “Chance of Admit” to categorical having values 0 and 1
#
# Students having the “Chance of Admit” value > 0.80, are assigned value 1, and
#
# Students having the “Chance of Admit” value < 0.80, are assigned value 0
#
# Where 0: Low chance of Admission and 1: High chance of admission

# %%
L=list(dataset['Chance of Admit '].values)
for i in L:
  if i>0.80:
    dataset['Chance of Admit '] = dataset['Chance of Admit '].replace({i : 1})
  else:
    dataset['Chance of Admit '] = dataset['Chance of Admit '].replace({i : 0})


data['Chance of Admit ']=data['Chance of Admit '].astype(int)
print(data['Chance of Admit '])
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 495    1
# 496    1
# 497    1
# 498    0
# 499    1
# Name: Chance of Admit , Length: 500, dtype: int64

# %% [markdown]
# Q5).Build a Decision Tree classifier, to predict whether a
# student has a low or high chance of admission to a chosen
# university. Perform Hyperparameter Tuning to improve
# the accuracy of the model.

# %% [markdown]
# Build a Decision Tree classifier

# %%
x = dataset.drop(['Chance of Admit '],axis=1)
y= dataset['Chance of Admit ']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
A_1=accuracy_score(y_test,y_pred)
A_1
# Out:
# 0.96

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[92,  3],
#        [ 2, 28]])

# %%
z=classification_report(y_test,y_pred)
print(z)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97        95
#            1       0.90      0.93      0.92        30
#
#     accuracy                           0.96       125
#    macro avg       0.94      0.95      0.95       125
# weighted avg       0.96      0.96      0.96       125

# %% [markdown]
# Hyperparameter Tuning to improve the accuracy of the model

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

# %%
from sklearn import decomposition

pca = decomposition.PCA()

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline(steps=[('sc', sc), 
                       ('pca', pca),
                       ('decisiontree', model)])

# %%
n_components = list(range(1,x.shape[1]+1,1))

# %%
criterion = ['gini', 'entropy']

max_depth = [2,4,6,8,12]

# %%
parameters = dict(pca__n_components=n_components,
                  decisiontree__criterion=criterion,
                  decisiontree__max_depth=max_depth)

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

clf = GridSearchCV(pipe, parameters)

# %%
clf.fit(x, y)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('sc', StandardScaler()), ('pca', PCA()),
#                                        ('decisiontree',
#                                         DecisionTreeClassifier())]),
#              param_grid={'decisiontree__criterion': ['gini', 'entropy'],
#                          'decisiontree__max_depth': [2, 4, 6, 8, 12],
#                          'pca__n_components': [1, 2, 3, 4, 5, 6, 7]})

# %%
print('Best Criterion:', clf.best_estimator_.get_params()['decisiontree__criterion'])
# Out:
# Best Criterion: entropy

# %%
print('Best max_depth:', clf.best_estimator_.get_params()['decisiontree__max_depth'])
# Out:
# Best max_depth: 4

# %%
print('Best Number Of Components:', clf.best_estimator_.get_params()['pca__n_components'])
# Out:
# Best Number Of Components: 6

# %%
print(clf.best_estimator_.get_params()['decisiontree'])
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
CV_Result = cross_val_score(clf, x, y, cv=4, n_jobs=-1)

# %%
print(CV_Result)
# Out:
# [0.944 0.904 0.888 0.936]

# %%
print(CV_Result.mean())
# Out:
# 0.9179999999999999

# %%
print(CV_Result.std())
# Out:
# 0.022891046284519184

# %% [markdown]
# Q.6 Build a Random Forest classifier, to predict whether a student has a low or high chance of admission to a chosen university.

# %% [markdown]
# Build a Random Forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

clf_rf = RandomForestClassifier(n_estimators = 200, criterion = 'entropy', 
                                min_samples_split = 10, min_samples_leaf = 9, max_features = "auto",
                                random_state = 500, max_depth = 12)

# %%
clf_fit = clf_rf.fit(x_train, y_train) 
y_pred = clf_fit.predict(x_test)

# %%
A_2=accuracy_score(y_test, y_pred)
A_2
# Out:
# 0.968

# %%
y_proba = clf_fit.predict_proba(x_test)

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[93  2]
#  [ 2 28]]

# %%
y_predicted = y_proba[:,1]
print(y_predicted)
# Out:
# [3.52593897e-02 7.96753273e-01 2.67699524e-01 9.10773022e-01
#  2.27661169e-03 3.73010252e-03 1.59196128e-03 8.86846111e-02
#  1.59196128e-03 1.07548772e-01 4.31369021e-03 8.08457417e-02
#  1.12745098e-03 2.45410527e-01 9.21462876e-01 3.70370370e-04
#  4.68694014e-01 6.68834842e-03 2.24119283e-01 3.44857893e-03
#  0.00000000e+00 1.07696018e-01 0.00000000e+00 9.97025183e-01
#  7.59892014e-01 6.02721721e-02 2.15546555e-01 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.92218478e-02 0.00000000e+00
#  2.37712957e-02 6.25342245e-01 1.85661765e-03 3.76005698e-02
#  7.87714884e-01 9.17391412e-01 1.19989326e-03 1.12745098e-03
#  1.83316539e-02 9.83337292e-01 9.34769887e-01 5.30342415e-02
#  2.20178603e-01 3.94153825e-01 9.98095389e-01 5.83979693e-01
#  4.82508397e-02 1.28329155e-02 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 3.60925279e-01 3.11271649e-02 8.53294821e-01
#  3.70370370e-04 8.98798766e-01 1.83671652e-03 1.43560606e-03
# ...

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
fpr, tpr, thresholds = roc_curve(y_test,y_predicted)
roc_auc = auc(fpr,tpr)
print("Area under the curve for first model",roc_auc)
# Out:
# Area under the curve for first model 0.9950877192982457

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(fpr, tpr, color = 'orange', lw = 2, label = 'ROC curve (area under curve =%0.2f)'%roc_auc)

plt.plot([0,1],[0,1], color = 'darkgrey',lw = 2,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.xlabel('False Positive Rate (1-Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('ROC Curve for first model')
plt.legend(loc = "upper left")
plt.show()

# %%
clf_rf2 = RandomForestClassifier(n_estimators = 100, criterion = 'gini', 
                                min_samples_split = 2, min_samples_leaf = 5, max_features = "auto",
                                random_state = 100, max_depth = 3)

# %%
clf_fit_2 = clf_rf2.fit(x_train, y_train) 
y_pred_2 = clf_fit_2.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
A_3=accuracy_score(y_test, y_pred_2)
A_3
# Out:
# 0.968

# %%
y_proba_2 = clf_fit.predict_proba(x_test)

# %%
y_predicted_2 = y_proba_2[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_predicted_2)
from sklearn.metrics import auc
roc_auc = auc(fpr,tpr)
print("Area under the curve for the second model",roc_auc)
# Out:
# Area under the curve for the second model 0.9950877192982457

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(fpr, tpr, color = 'orange', lw = 2, label = 'ROC curve (area under curve =%0.2f)'%roc_auc)

plt.plot([0,1],[0,1], color = 'darkgrey',lw = 2,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.xlabel('False Positive Rate (1-Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('ROC Curve for second model')
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# Q7). Also use Ensemble Modelling techniques, to predict whether a student has a low or high chance of admission to a chosen university.

# %% [markdown]
# Bagging technique

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn import tree
from sklearn import metrics
meta_estimator = BaggingClassifier(tree.DecisionTreeClassifier(random_state=10))
meta_estimator.fit(x_train, y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=10))

# %%
bag_Score = metrics.roc_auc_score(y_test, y_pred)
print('Bagging score :',bag_Score)
# Out:
# Bagging score : 0.956140350877193

# %% [markdown]
# AdaBoost technique

# %%
from sklearn.ensemble import AdaBoostClassifier
adaboost = AdaBoostClassifier(random_state=10)
adaboost.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(random_state=10)

# %%
y_pred_adaboost  = adaboost.predict(x_test)

# %%
adaboost_score = metrics.roc_auc_score(y_test, y_pred_adaboost)

# %%
result = pd.DataFrame()
result['Model'] = ['Bagging','AdaBoost']
result['AUC roc curve'] = [bag_Score,adaboost_score]
result
# Out:
#       Model  AUC roc curve
# 0   Bagging       0.956140
# 1  AdaBoost       0.945614

# %% [markdown]
# Q.8 Compare all of the models and justify your choice about the optimum model.

# %%
Overall_result= pd.DataFrame()
Overall_result['Model'] = ['Decision Tree classifier','Hyperparameter Tuning','Random Forest classifier','Bagging','AdaBoost']
Overall_result['Score'] = [A_1,A_2,A_3,bag_Score,adaboost_score]
Overall_result
# Out:
#                       Model     Score
# 0  Decision Tree classifier  0.960000
# 1     Hyperparameter Tuning  0.968000
# 2  Random Forest classifier  0.968000
# 3                   Bagging  0.956140
# 4                  AdaBoost  0.945614
